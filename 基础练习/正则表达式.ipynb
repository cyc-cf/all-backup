# %%
import re
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('7.8.xlsx')
data
# Out:
#              任务编码      任务名称 任务状态  发起人   直接部门                发起时间  \
# 0    2.110090e+15        日报  已完成   曹永  销售部天津 2021-07-08 20:35:13
# 1             NaN       NaN  NaN   曹永  销售部天津                 NaT
# 2             NaN       NaN  NaN   曹永  销售部天津                 NaT
# 3             NaN       NaN  NaN   曹永  销售部天津                 NaT
# 4    2.110090e+15        赵淼  已完成   赵淼   北京一区 2021-07-08 00:09:07
# ..            ...       ...  ...  ...    ...                 ...
# 185  2.110090e+15  7月8日工作日报  已完成  刘心宇   北京三区 2021-07-09 07:49:28
# 186           NaN       NaN  NaN  刘心宇   北京三区                 NaT
# 187           NaN       NaN  NaN  刘心宇   北京三区                 NaT
# 188           NaN       NaN  NaN  刘心宇   北京三区                 NaT
# 189           NaN       NaN  NaN  刘心宇   北京三区                 NaT
#
#                    完成时间       流程版本  \
# 0   2021-07-09 09:22:23  023806-13
# 1                   NaT        NaN
# 2                   NaT        NaN
# 3                   NaT        NaN
# 4   2021-07-08 11:36:21  023806-13
# ..                  ...        ...
# 185 2021-07-09 11:27:18  023806-13
# 186                 NaT        NaN
# 187                 NaT        NaN
# 188                 NaT        NaN
# 189                 NaT        NaN
#
#                                           businessCode 当前处理节点  ... 加签原因.4  \
# 0    {jobInitiator:11138558; jobIssuedDayType:work_...    NaN  ...    NaN
# 1                                                  NaN    NaN  ...    NaN
# 2                                                  NaN    NaN  ...    NaN
# 3                                                  NaN    NaN  ...    NaN
# 4    {jobInitiator:11138558; jobIssuedDayType:work_...    NaN  ...    NaN
# ..                                                 ...    ...  ...    ...
# 185  {jobInitiator:11138558; jobIssuedDayType:work_...    NaN  ...    NaN
# 186                                                NaN    NaN  ...    NaN
# 187                                                NaN    NaN  ...    NaN
# 188                                                NaN    NaN  ...    NaN
# 189                                                NaN    NaN  ...    NaN
#
#     操作人.29  操作时间.29 驳回原因.3 附件.21 操作人.30 操作时间.30 反馈内容.4 附件.22 父流程单号
# 0      NaN      NaN    NaN   NaN    NaN     NaN    NaN   NaN   NaN
# 1      NaN      NaN    NaN   NaN    NaN     NaN    NaN   NaN   NaN
# 2      NaN      NaN    NaN   NaN    NaN     NaN    NaN   NaN   NaN
# 3      NaN      NaN    NaN   NaN    NaN     NaN    NaN   NaN   NaN
# 4      NaN      NaN    NaN   NaN    NaN     NaN    NaN   NaN   NaN
# ..     ...      ...    ...   ...    ...     ...    ...   ...   ...
# 185    NaN      NaN    NaN   NaN    NaN     NaN    NaN   NaN   NaN
# 186    NaN      NaN    NaN   NaN    NaN     NaN    NaN   NaN   NaN
# 187    NaN      NaN    NaN   NaN    NaN     NaN    NaN   NaN   NaN
# 188    NaN      NaN    NaN   NaN    NaN     NaN    NaN   NaN   NaN
# 189    NaN      NaN    NaN   NaN    NaN     NaN    NaN   NaN   NaN
#
# [190 rows x 228 columns]

# %%
df =data[['发起人','今日拜访客户名称','明日预约客户']]
df
# Out:
#      发起人        今日拜访客户名称                 明日预约客户
# 0     曹永            爱情地产                   花椒直播
# 1     曹永            中环天仪                    金力研
# 2     曹永            天匠动画                   可可猩球
# 3     曹永             阿里云                   密室联盟
# 4     赵淼         欲飞舞蹈望京店                北京中汽新动力
# ..   ...             ...                    ...
# 185  刘心宇     北京星立方培训有限公司  北京万禾景盛文化传媒有限公司（龙门艺术区）
# 186  刘心宇    北京星光娱乐基地有限公司           北京逗游网络技术有限公司
# 187  刘心宇  北京其来有自教育科技有限公司             汇天网络科技有限公司
# 188  刘心宇          北京动漫大厦         北京点滴贴士网络科技有限公司
# 189  刘心宇             NaN      北京信邦同安新能源科技股份有限公司
#
# [190 rows x 3 columns]

# %%
df.groupby('发起人').agg({'今日拜访客户名称','明日预约客户'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-b19a02337508> in <module>
# ----> 1 df.groupby('发起人').agg({'今日拜访客户名称','明日预约客户'})
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     949         func = maybe_mangle_lambdas(func)
#     950
# --> 951         result, how = self._aggregate(func, *args, **kwargs)
#     952         if how is None:
#     953             return result
#
# D:\Anaconda\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     478         elif is_list_like(arg):
#     479             # we require a list, but not an 'str'
# --> 480             return self._aggregate_multiple_funcs(arg, _axis=_axis), None
#     481         else:
#     482             result = None
#
# D:\Anaconda\lib\site-packages\pandas\core\base.py in _aggregate_multiple_funcs(self, arg, _axis)
#     524                 colg = self._gotitem(col, ndim=1, subset=obj.iloc[:, index])
#     525                 try:
# --> 526                     new_res = colg.aggregate(arg)
#     527                 except (TypeError, DataError):
#     528                     pass
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     244             # but not the class list / tuple itself.
#     245             func = maybe_mangle_lambdas(func)
# --> 246             ret = self._aggregate_multiple_funcs(func)
#     247             if relabeling:
#     248                 ret.columns = columns
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_multiple_funcs(self, arg)
#     317                 obj._reset_cache()
#     318                 obj._selection = name
# --> 319             results[base.OutputKey(label=name, position=idx)] = obj.aggregate(func)
#     320
#     321         if any(isinstance(x, DataFrame) for x in results.values()):
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     238
#     239         if isinstance(func, str):
# --> 240             return getattr(self, func)(*args, **kwargs)
#     241
#     242         elif isinstance(func, abc.Iterable):
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute '今日拜访客户名称'

# %%
df.groupby('发起人').agg({})
# Out:
#     今日拜访客户名称                                     明日预约客户         \
#        count unique                     top freq  count unique
# 发起人
# 万二雷        6      6                    安信天行    1      5      5
# 关新         4      4                      联科    1      4      4
# 刘刚         5      5           欧菲斯办公伙伴南京有限公司    1      5      5
# 刘心宇        8      8            天津众鑫信息咨询有限公司    1      9      9
# 刘戌望        4      3                   太平洋保险    2      4      4
# 刘昭辉        4      4            上海鼓郡文化传播有限公司    1      4      4
# 司鹏         4      4                   新希望集团    1      5      5
# 吴健         4      4            中证天通管理咨询有限公司    1      4      4
# 周晓         4      4                喜乐空间有限公司    1      5      5
# 周泉         4      4        珍岛信息技术（上海）股份有限公司    1      4      3
# 孙辉         5      5              南京商厦股份有限公司    1      5      5
# 安健         4      4                     剧本杀    1      4      4
# 宫雪         4      4        趋势（北京）文化传媒股份有限公司    1      4      4
# 张俊         4      4                    墨迹天气    1      4      4
# 张敏         4      4                  博图纵横科技    1      4      4
# 张永兴        4      4                  经开·壹中心    1      4      4
# 张永生        5      5      南京江原安迪科正电子研究发展有限公司    1      5      5
# 张莉         4      4                     乐元素    1      4      4
# 彭敏         8      8         中特检管道工程（北京）有限公司    1      8      8
# 成昭龙        4      4           华歌尔（中国）时装有限公司    1      5      5
# 房公彪        8      8                   宝坻区人力    1      3      3
# 文胜         4      4            北京京东世纪贸易有限公司    1      4      4
# 曹永         4      4                    中环天仪    1      4      4
# 李博         5      5  南京河西会议展览有限责任公司国际博览会议中心    1      5      5
# 王世会        4      4           京东科技有限公司华北分公司    1      4      4
# 王俊雄        5      5                 广汽传祺冠崴店    1      4      4
# 王淼         4      4            上海竞综文化传媒有限公司    1      4      4
# 王航         5      5                    游娱联盟    1      5      5
# 程金刚        4      4           北京河狸家信息技术有限公司    1      4      4
# 苏建影        4      4              北京中影股份有限公司    1      4      4
# 苗林         4      4              北京市白盆窑物流中心    1      4      4
# 薛松         4      4          北京快友世纪科技股份有限公司    1      4      4
# 许惠民        4      4                  知言网络科技    1      4      4
# 赵永福        4      4              中科金审科技有限公司    1      4      4
# 赵淼         8      8         东风本田汽车博诚特约销售服务店    1      8      8
# 陈家兴        5      5            上海中路(集团)有限公司    1      6      6
# 高彬         4      4           北京费拉蒙艺术培训有限公司    1      4      4
# 高彬强        4      4                    长藤鬼校    1      4      4
# 黄海         4      4            广东趣炫网络股份有限公司    1      4      4
# 齐涛         2      2            北京北工大科技园有限公司    1      4      4
#
#
#                    top freq
# 发起人
# 万二雷               五合国际    1
# 关新                  日升    1
# 刘刚        南京恒科物业管理有限公司    1
# 刘心宇  北京信邦同安新能源科技股份有限公司    1
# 刘戌望                康宝莱    1
# 刘昭辉             魔方剧情密室    1
# 司鹏                 蓝可可    1
# 吴健       北京佰加佰教育咨询有限公司    1
# 周晓        北京达邦文化传媒有限公司    1
# 周泉        上海喔趣信息科技有限公司    2
# 孙辉          南京银行股份有限公司    1
# 安健                筑梦之星    1
# 宫雪    北京开运联合信息技术股份有限公司    1
# 张俊      北京万鑫同创物业管理有限公司    1
# 张敏              蜂鸟企业管理    1
# 张永兴           国防科技园TCL    1
# 张永生     ；南京益屋不动产经纪有限公司    1
# 张莉                 北工大    1
# 彭敏        北京海杭通讯科技有限公司    1
# 成昭龙              宝兰德软件    1
# 房公彪              九经路人力    1
# 文胜       北京叁零壹文化传播有限公司    1
# 曹永                花椒直播    1
# 李博      明胜（南京）商业管理有限公司    1
# 王世会    中国移动北京分公司城区三分公司    1
# 王俊雄                国粹苑    1
# 王淼        北京小苗财税服务有限公司    1
# 王航                 趣头条    1
# 程金刚       北京住总集团有限责任公司    1
# 苏建影         北京惊悚大师沉浸密室    1
# 苗林             禧月阁月子中心    1
# 薛松    北京品众互动网络营销技术有限公司    1
# 许惠民                百吉福    1
# 赵永福        麦迪斯医疗器械有限公司    1
# 赵淼     东风本田汽车博诚特约销售服务店    1
# 陈家兴       广州致景信息科技有限公司    1
# 高彬             金夫人婚纱摄影    1
# 高彬强              716直播    1
# 黄海         广州铂安会美容有限公司    1
# 齐涛                长城华冠    1

# %%
s='都是分开了对加油简介事故大叔记性差倒萨的有'

# %%
x = re.search(r'对(.*?)事故',s)
x
# Out:
# <re.Match object; span=(5, 12), match='对加油简介事故'>

# %%
x.group(1)

# %%
sor=[1,2,3,5,6,7]
len(sor)
# Out:
# 6

# %%
sor[1]
# Out:
# 2

# %%
import requests
import pandas as pd
import re
import os
import time
from bs4 import BeautifulSoup

# %%
url = 'http://www.safehoo.com/Case/'
headers = {
        'Cookie':'UM_distinctid=1784ded06e1ae4-07a28a5ae96d69-416d2310-13c680-1784ded06e29b2;  CNZZDATA1254435984=1164384084-1616211641-nul1%7C1616211641;cfduid=d108ba1322724f4b3520d69fd1ecd52 b31618911278;ASP.NET_SessionId=u141lcq5ye0kqcixij4nt0im;Hm_ lvt_c1ab114862618ab1c8ff0afaede5a797=1618911279',
        'User-Agent':'Mozilla/5.0 (Windows NT 10.0;WOW64) AppleWebKit/537.36 (KHTML,like Gecko) Chrome/84.0.4147.89 Safari/537.36 SLBrowser/7.0.0.4071 SLBChan/30',
        'Referrer':'http://www.safehoo.com/Case/'
        }
html = requests.get(url,headers=headers)
html.encoding = html.apparent_encoding

urllst = 'http://www.safehoo.com/Case/Case/Hit/'
html = requests.get(urllst,headers=headers)
html.encoding = html.apparent_encoding
pattern = re.compile(r'<a href="(.*?)" target="_blank" title="标题：(.*?)">.*?</a><img src="(.*?) alt="热门内容">')
info = re.findall(pattern, html.text)
datals = []
for i in info:
    dic = {}
    dic['_id'] = i[1]
    dic['title'] = i[2]
    url_ = i[0]
    detail_url = filter_url(url_)
    dic['detail_url'] = detail_url
    dic['contents'] = get_content(detail_url)
    datals.append(dic)
datals
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-9-e73e215a07d1> in <module>
#      21     detail_url = filter_url(url_)
#      22     dic['detail_url'] = detail_url
# ---> 23     dic['contents'] = get_content(detail_url)
#      24     datals.append(dic)
#      25 datals
#
# <ipython-input-8-fdfb6959452a> in get_content(detail_url)
#      30
#      31 def get_content(detail_url):
# ---> 32     html = requests.get(detail_url,headers=headers)
#      33     html.encoding = html.apparent_encoding
#      34     soup = BeautifulSoup(html.text,'lxml')
#
# D:\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# D:\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# D:\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     514             hooks=hooks,
#     515         )
# --> 516         prep = self.prepare_request(req)
#     517
#     518         proxies = proxies or {}
#
# D:\Anaconda\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     447
#     448         p = PreparedRequest()
# --> 449         p.prepare(
#     450             method=request.method.upper(),
#     451             url=request.url,
#
# D:\Anaconda\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     312
#     313         self.prepare_method(method)
# --> 314         self.prepare_url(url, params)
#     315         self.prepare_headers(headers)
#     316         self.prepare_cookies(cookies)
#
# D:\Anaconda\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     386             error = error.format(to_native_string(url, 'utf8'))
#     387
# --> 388             raise MissingSchema(error)
#     389
#     390         if not host:
#
# MissingSchema: Invalid URL 'None': No schema supplied. Perhaps you meant http://None?

# %%
def get_url():
    
    urllst = 'http://www.safehoo.com/Case/Case/Hit/'
       
    return urllst
    
def get_data(urllst):
    html = requests.get(urllst,headers=headers)
    html.encoding = html.apparent_encoding
    pattern = re.compile(r'<a href="(.*?)" target="_blank" title="标题：(.*?)">.*?</a><img src="(.*?) alt="热门内容">')
    info = re.findall(pattern, html.text)
    datals = []
    for i in info:
        dic = {}
        dic['_id'] = i[1]
        dic['title'] = i[2]
        dic['read_num'] = i[3]
        dic['upload_time'] = i[4]
        url_ = i[0]
        detail_url = filter_url(url_)
        dic['detail_url'] = detail_url
        dic['contents'] = get_content(detail_url)
        datals.append(dic)
    return datals

def filter_url(url_):
    base_path = url_.split('/')[-2]
    detail_url = os.path.join('http://www.safehoo.com/Case/Case/Hit/', base_path)


def get_content(detail_url):
    html = requests.get(detail_url,headers=headers)
    html.encoding = html.apparent_encoding
    soup = BeautifulSoup(html.text,'lxml')
    contents = soup.find('div', class_="c_content_text").text
    contents = re.sub(r'/s+',contents)
    return contents

# %%
success_ls = []
error_ls =[]
print("正在爬取中。。。")
urllst = 'http://www.safehoo.com/Case/Case/Hit/'
try:
    success_ls.extend(get_data(urllst))
    print('已经爬取{}条'.format(len(success_ls)))
    time.sleep(3)
    print('爬累了，休息中。。。')
except Exception as e:
    print('爬取失败，目标网址为：',urllst)
    error_ls.append(urllst)
# Out:
# 正在爬取中。。。
# 爬取失败，目标网址为： http://www.safehoo.com/Case/Case/Hit/
