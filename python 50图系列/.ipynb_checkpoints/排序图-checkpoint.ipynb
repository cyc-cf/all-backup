# %%
plt.rcParams['font.sans-serif'] = ['Simhei']
plt.rcParams['axes.unicode_minus'] = False

# %%
排序图：对比大小

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.vlines() #绘制竖线的函数

# %%
x =[1,2,3,4,5]
y = [12,32,24,16,20]

# %%
y.sort()
plt.vlines(x=x,ymin=0,ymax=y,linewidth = 10,colors='red',linestyles = 'solid')

# %%
df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# <ipython-input-24-ee42c2301382> in <module>
# ----> 1 df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     432     # though mypy handling of conditional imports is difficult.
#     433     # See https://github.com/python/mypy/issues/1297
# --> 434     fp_or_buf, _, compression, should_close = get_filepath_or_buffer(
#     435         filepath_or_buffer, encoding, compression
#     436     )
#
# D:\Anaconda\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     181     if isinstance(filepath_or_buffer, str) and is_url(filepath_or_buffer):
#     182         # TODO: fsspec can also handle HTTP via requests, but leaving this unchanged
# --> 183         req = urlopen(filepath_or_buffer)
#     184         content_encoding = req.headers.get("Content-Encoding", None)
#     185         if content_encoding == "gzip":
#
# D:\Anaconda\lib\site-packages\pandas\io\common.py in urlopen(*args, **kwargs)
#     135     import urllib.request
#     136
# --> 137     return urllib.request.urlopen(*args, **kwargs)
#     138
#     139
#
# D:\Anaconda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# D:\Anaconda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# D:\Anaconda\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# D:\Anaconda\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# D:\Anaconda\lib\urllib\request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# D:\Anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
#    1353                 raise URLError(err)
# -> 1354             r = h.getresponse()
#    1355         except:
#    1356             h.close()
#
# D:\Anaconda\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# D:\Anaconda\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# D:\Anaconda\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# D:\Anaconda\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# D:\Anaconda\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# D:\Anaconda\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。

# %%
df_raw.head()

# %%
name = ["汽车制造商","型号名称","发动机排量(L)","制造年份","气缸数量","手动/自动"
              ,"驱动类型","城市里程/加仑","公路里程/加仑","汽油种类","车辆种类"]

# %%
#聚合每个品牌的车辆，并求其均值
df = df_raw[['cty','manufacturer']].groupby('manufacturer').mean()

# %%
df.sort_values('cty',inplace = True)

# %%
df.head()
# Out:
#                     cty
# manufacturer
# lincoln       11.333333
# land rover    11.500000
# dodge         13.135135
# mercury       13.250000
# jeep          13.500000

# %%
df.reset_index(inplace = True)

# %%
plt.figure(figsize=(16,10))
plt.vlines(x=df.index,ymin=0,ymax=df.cty,
          color = 'r',alpha=0.5,linewidth=5)

# %%
import matplotlib.patches as patches

# %% [markdown]
# #### plt.subplots生成两个对象：fig（画布，包括多个子图）  ax（子图对象，呈现在fig上的）

# %%
#facecolor 画布的填充色
fig,ax = plt.subplots(figsize=(16,10),facecolor ='white',dpi=80)
ax.vlines(x= df.index,ymin=0,ymax=df.cty,color='firebrick',alpha=0.7,linewidth=20)

# %% [markdown]
# #### 为柱状图添加注解 text函数:一次只能添加一个，所以用循环

# %%
fig,ax = plt.subplots(figsize=(16,10),facecolor ='white',dpi=80)
ax.vlines(x= df.index,ymin=0,ymax=df.cty,color='firebrick',alpha=0.7,linewidth=20)

for i, cty in enumerate(df.cty):
    ax.text(i,cty+0.5,round(cty,1),horizontalalignment='center')
    # round函数对浮点函数近似取值，保留几位小数
    # horizontalalignment 对于规定的坐标轴，文字显示的地方

# %% [markdown]
# #### 装饰图像

# %%
fig,ax = plt.subplots(figsize=(16,10),facecolor ='white',dpi=80)
ax.vlines(x= df.index,ymin=0,ymax=df.cty,color='firebrick',alpha=0.7,linewidth=20)

for i, cty in enumerate(df.cty):
    ax.text(i,cty+0.5,round(cty,1),horizontalalignment='center')
    # round函数对浮点函数近似取值，保留几位小数
    # horizontalalignment 对于规定的坐标轴，文字显示的地方
ax.set_title('城市里程柱状图',fontdict={'size':22})
ax.set(ylabel='城市公里/加仑',ylim=(0,30))

plt.xticks(df.index,df.manufacturer.str.upper(),
           rotation=60,horizontalalignment='right',fontsize=12)
# Out:
# ([<matplotlib.axis.XTick at 0x1f12194de80>,
#   <matplotlib.axis.XTick at 0x1f12194de50>,
#   <matplotlib.axis.XTick at 0x1f11f90ce50>,
#   <matplotlib.axis.XTick at 0x1f11fc5c940>,
#   <matplotlib.axis.XTick at 0x1f11fc5ce50>,
#   <matplotlib.axis.XTick at 0x1f11fc653a0>,
#   <matplotlib.axis.XTick at 0x1f11fc658b0>,
#   <matplotlib.axis.XTick at 0x1f11fc65dc0>,
#   <matplotlib.axis.XTick at 0x1f11fc6a310>,
#   <matplotlib.axis.XTick at 0x1f11fc6a820>,
#   <matplotlib.axis.XTick at 0x1f11fc65520>,
#   <matplotlib.axis.XTick at 0x1f11fc5c5b0>,
#   <matplotlib.axis.XTick at 0x1f11fc6ab80>,
#   <matplotlib.axis.XTick at 0x1f11fc6f0d0>,
#   <matplotlib.axis.XTick at 0x1f11fc6f5e0>],
#  [Text(0, 0, 'LINCOLN'),
#   Text(1, 0, 'LAND ROVER'),
#   Text(2, 0, 'DODGE'),
#   Text(3, 0, 'MERCURY'),
#   Text(4, 0, 'JEEP'),
#   Text(5, 0, 'FORD'),
#   Text(6, 0, 'CHEVROLET'),
#   Text(7, 0, 'PONTIAC'),
#   Text(8, 0, 'AUDI'),
#   Text(9, 0, 'NISSAN'),
#   Text(10, 0, 'TOYOTA'),
#   Text(11, 0, 'HYUNDAI'),
#   Text(12, 0, 'SUBARU'),
#   Text(13, 0, 'VOLKSWAGEN'),
#   Text(14, 0, 'HONDA')])

# %% [markdown]
# ### patches

# %%
patches.rectangle 绘制长方形

# %%
import matplotlib.patches as patches

# %%
fig,ax = plt.subplots(figsize=(16,10),facecolor ='white',dpi=80)
ax.vlines(x= df.index,ymin=0,ymax=df.cty,color='firebrick',alpha=0.7,linewidth=20)

for i, cty in enumerate(df.cty):
    ax.text(i,cty+0.5,round(cty,1),horizontalalignment='center')
    # round函数对浮点函数近似取值，保留几位小数
    # horizontalalignment 对于规定的坐标轴，文字显示的地方
ax.set_title('城市里程柱状图',fontdict={'size':22})
ax.set(ylabel='城市公里/加仑',ylim=(0,30))

plt.xticks(df.index,df.manufacturer.str.upper(),
           rotation=60,horizontalalignment='right',fontsize=12)
p1 = patches.Rectangle((0.57,-0.005),#长方形所在的左下角坐标
                       width=0.33, #长方形的宽
                       height=0.13,#长方形的高
                       alpha =0.1, #透明度
                       facecolor ='green',#矩阵颜色
                       transform = fig.transFigure)#确保矩形显示在图像最上方
p2 = patches.Rectangle((0.124,-0.005),
                       width = 0.446,height = 0.13,
                       alpha =0.1,facecolor='red',
                      transform = fig.transFigure)#进行对象的转换，fig.transFigure表示
                                                #根据矩形所在的位置进行对象转换，以确保举行显示在最上方
p3=patches.Rectangle((0.67,0.115),width=0.04,height=0.48,
                     alpha=0.1,facecolor='red',
                   transform = fig.transFigure)
fig.add_artist(p3)
#对画布添加对象
fig.add_artist(p1) 
fig.add_artist(p2)
plt.show()

# %%
ax.add_patch作用的对象是ax,也就是坐标轴内的范围和标题/坐标轴的名称，但不包含这些背后的画布
ax.add_artist 功能同上
fig没有add_patch功能
fig.add_artist
