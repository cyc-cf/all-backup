# %%
import pandas as pd
import numpy as np

# %%
data_1 = pd.read_csv('D:\Google\赛题数据\数据.csv')
data_1
# Out:
#           id             level_1      level_2           level_3  \
# 0          0   工业/危化品类（现场）—2016版      （二）电气安全  6、移动用电产品、电动工具及照明
# 1          1   工业/危化品类（现场）—2016版      （一）消防检查            1、防火巡查
# 2          2   工业/危化品类（现场）—2016版      （一）消防检查            2、防火检查
# 3          3   工业/危化品类（现场）—2016版      （一）消防检查            1、防火巡查
# 4          4   工业/危化品类（现场）—2016版      （一）消防检查            1、防火巡查
# ...      ...                 ...          ...               ...
# 11995  11995  商贸服务教文卫类（基础）—2016版    （四）安全教育培训          1、员工安全教育
# 11996  11996   工业/危化品类（现场）—2016版      （二）电气安全     3、电气线路及电源插头插座
# 11997  11997   工业/危化品类（现场）—2016版  （三）机械设备安全防护            2、人身防护
# 11998  11998   工业/危化品类（现场）—2016版      （四）作业环境           2、通风与照明
# 11999  11999     纯办公场所（现场）—2016版      （一）消防安全            2、消防通道
#
#                                                  level_4  \
# 0      1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。
# 1                               3、消防设施、器材和消防安全标志是否在位、完整；
# ...

# %%
data_2 = pd.read_csv('D:\Google\赛题数据\数据1.csv')
data_2
# Out:
#           id             level_1  level_2        level_3  \
# 0          0     交通运输类（现场）—2016版  （一）消防安全         2、防火检查
# 1          1   工业/危化品类（选项）—2016版    （二）仓库         1、一般要求
# 2          2   工业/危化品类（现场）—2016版  （一）消防检查         1、防火巡查
# 3          3  商贸服务教文卫类（现场）—2016版  （二）电气安全  3、电气线路及电源插头插座
# 4          4  商贸服务教文卫类（现场）—2016版  （一）消防检查         1、防火巡查
# ...      ...                 ...      ...            ...
# 17995  17995   工业/危化品类（现场）—2016版  （二）电气安全         7、临时用电
# 17996  17996   工业/危化品类（现场）—2016版  （二）电气安全     2、配电箱（柜、板）
# 17997  17997   工业/危化品类（现场）—2016版  （一）消防检查         1、防火巡查
# 17998  17998   工业/危化品类（现场）—2016版  （一）消防检查         1、防火巡查
# 17999  17999  商贸服务教文卫类（现场）—2016版  （四）场所环境         1、作业通道
#
#                                                  level_4  \
# 0                           2、安全疏散通道、疏散指示标志、应急照明和安全出口情况。
# 1                                  1、库房内储存物品应分类、分堆、限额存放。
# 2                               3、消防设施、器材和消防安全标志是否在位、完整；
# ...

# %%
data_3 = pd.read_csv('D:\Google\赛题数据\样例.csv')
data_3
# Out:
#           id  label
# 0          0      1
# 1          1      0
# 2          2      1
# 3          3      1
# 4          4      1
# ...      ...    ...
# 17995  17995      0
# 17996  17996      0
# 17997  17997      1
# 17998  17998      0
# 17999  17999      0
#
# [18000 rows x 2 columns]

# %%
data_1.to_excel('D:\Google\赛题数据\data_1.xlsx',encoding='UTF-8')

# %%
data_2.to_excel('D:\Google\赛题数据\data_2.xlsx',encoding='UTF-8')

# %%
data_3.to_excel('D:\Google\赛题数据\data_3.xlsx',encoding='UTF-8')
